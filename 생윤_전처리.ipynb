# %% [markdown]
# # 0. 패키지 설치 및 환경설정, 모듈 로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install "unstructured[pdf]"
# Out:
# Collecting unstructured[pdf]
#   Downloading unstructured-0.17.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (5.2.0)
# Collecting filetype (from unstructured[pdf])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured[pdf])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (5.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (4.13.4)
# Collecting emoji (from unstructured[pdf])
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured[pdf])
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured[pdf])
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured[pdf])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (2.0.2)
# Collecting rapidfuzz (from unstructured[pdf])
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting backoff (from unstructured[pdf])
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (4.13.2)
# Collecting unstructured-client (from unstructured[pdf])
#   Downloading unstructured_client-0.36.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (1.17.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (5.9.5)
# Collecting python-oxmsg (from unstructured[pdf])
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.11/dist-packages (from unstructured[pdf]) (1.1)
# Collecting onnx>=1.17.0 (from unstructured[pdf])
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting onnxruntime>=1.19.0 (from unstructured[pdf])
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting pdf2image (from unstructured[pdf])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pdfminer.six (from unstructured[pdf])
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Collecting pikepdf (from unstructured[pdf])
#   Downloading pikepdf-9.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# Collecting pi-heif (from unstructured[pdf])
#   Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting pypdf (from unstructured[pdf])
#   Downloading pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting google-cloud-vision (from unstructured[pdf])
#   Downloading google_cloud_vision-3.10.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting effdet (from unstructured[pdf])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting unstructured-inference>=0.8.10 (from unstructured[pdf])
#   Downloading unstructured_inference-1.0.5-py3-none-any.whl.metadata (5.3 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[pdf])
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx>=1.17.0->unstructured[pdf]) (5.29.5)
# Collecting coloredlogs (from onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (25.2.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (24.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (1.13.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (0.0.20)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (0.32.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (3.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (2.6.0+cu124)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (1.0.15)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (4.52.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (1.7.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (1.15.3)
# Collecting pypdfium2 (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (11.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->unstructured[pdf]) (2.7)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured[pdf])
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured[pdf])
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[pdf]) (0.21.0+cu124)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[pdf]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-vision->unstructured[pdf]) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-vision->unstructured[pdf]) (1.26.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib->unstructured[pdf]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib->unstructured[pdf]) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->unstructured[pdf]) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->unstructured[pdf]) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->unstructured[pdf]) (2024.11.6)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six->unstructured[pdf]) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six->unstructured[pdf]) (43.0.3)
# Collecting Deprecated (from pikepdf->unstructured[pdf])
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting olefile (from python-oxmsg->unstructured[pdf])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->unstructured[pdf]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->unstructured[pdf]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->unstructured[pdf]) (2025.4.26)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[pdf]) (24.1.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[pdf]) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[pdf]) (2.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (0.16.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (6.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.4.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm->unstructured-inference>=0.8.10->unstructured[pdf]) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.19.0->unstructured[pdf]) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->unstructured-inference>=0.8.10->unstructured[pdf]) (0.21.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->unstructured-inference>=0.8.10->unstructured[pdf]) (1.1.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf])
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.0.2)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 59.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 64.5 MB/s eta 0:00:00
# Downloading unstructured_inference-1.0.5-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.0 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 14.2 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 33.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_cloud_vision-3.10.1-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.1/526.1 kB 44.8 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 67.5 MB/s eta 0:00:00
# Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.8 MB/s eta 0:00:00
# Downloading pikepdf-9.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 61.6 MB/s eta 0:00:00
# Downloading pypdf-5.6.0-py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 29.4 MB/s eta 0:00:00
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 17.6 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.7 MB/s eta 0:00:00
# Downloading unstructured-0.17.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 58.0 MB/s eta 0:00:00
# Downloading unstructured_client-0.36.0-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 kB 19.9 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.2 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 12.1 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 107.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=521d34fdc4e4f5153718a232c51b51331ae32238bebf7906cd438231305db916
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: filetype, unstructured.pytesseract, rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, pi-heif, pdf2image, onnx, olefile, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, langdetect, humanfriendly, emoji, Deprecated, backoff, typing-inspect, python-oxmsg, pikepdf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, unstructured-client, pdfminer.six, onnxruntime, nvidia-cusolver-cu12, dataclasses-json, unstructured, google-cloud-vision, unstructured-inference, effdet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed Deprecated-1.2.18 backoff-2.2.1 coloredlogs-15.0.1 dataclasses-json-0.6.7 effdet-0.4.1 emoji-2.14.1 filetype-1.2.0 google-cloud-vision-3.10.1 humanfriendly-10.0 langdetect-1.0.9 marshmallow-3.26.1 mypy-extensions-1.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 olefile-0.47 onnx-1.18.0 onnxruntime-1.22.0 pdf2image-1.17.0 pdfminer.six-20250506 pi-heif-0.22.0 pikepdf-9.8.1 pypdf-5.6.0 pypdfium2-4.30.1 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.13.0 typing-inspect-0.9.0 unstructured-0.17.2 unstructured-client-0.36.0 unstructured-inference-1.0.5 unstructured.pytesseract-0.3.15

# %%
# !apt-get install -y poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.8 [186 kB]
# Fetched 186 kB in 0s (374 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.8_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.8) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.8) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# %pip install huggingface_hub[hf_xet]
# Out:
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2025.4.26)

# %%
# !pip install langchain_huggingface

# %%
# %pip install -U langchain-community

# %%
# !pip install faiss-cpu

# %%
from unstructured.partition.pdf import partition_pdf
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.docstore.document import Document
import numpy as np
import pickle
import os

# %%
import os

os.environ['OPENAI_API_KEY'] = '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'

# %%
import os
from PIL import Image
from langchain.schema import Document
from langchain.vectorstores import FAISS
from transformers import CLIPProcessor, CLIPModel
from transformers import AutoTokenizer, AutoModel
import torch

# %% [markdown]
# # 1. PDF 업로드 및 이미지 저장

# %%
# 업로드된 PDF 경로
pdf_path = "/content/drive/MyDrive/EBS 2026학년도 수능특강 사회탐구영역 생활과 윤리(교사용).pdf"

# 이미지 저장 폴더
image_output_dir = "/content/drive/MyDrive/output_images"
os.makedirs(image_output_dir, exist_ok=True)

# PDF에서 텍스트 및 이미지 추출
elements = partition_pdf(
    filename=pdf_path,
    extract_images_in_pdf=True,
    infer_table_structure=True,


    chunking_strategy="by_title",
    max_characters=4000,
    new_after_n_chars=3800,
    combine_text_under_n_chars=2000,
    pdf_image_output_dir_path=image_output_dir,
)

# 일부 요소 출력 확인
for elem in elements[:5]:
    print(type(elem), "\n", elem, "\n---")
# Out:
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# <class 'unstructured.documents.elements.CompositeElement'>
#  : a sk en asi og ere EBSZ AIOIE wd EO Solas Play | AppStore EA 2026stH& +s Alaa
#
# ※ 본 HWP 파일을 타인에게 배포하는 경우 저작권법 제20조의 배포권 침해에 해당되어 형사고소 및 손 해배상 책임을 물을 수 있음을 알려 드립니다.
#
# ■본 파일은 EBS교재를 바탕으로 제작된 HWP문항파일로서 대한민국 고등학교 교사에게 사용 권한이 있
#
# 습니다.
#
# ■저작권은 EBS에 있으며, 파일의 전체 또는 일부를 인터넷 등을 통해서 공유할 수 없습니다. ■파일 편집 과정에서 일부 오류가 있을 수 있기 때문에 수업 및 평가자료에 활용할 때 주의 바랍니다.
#
# 교재명 EBS 2026학년도 수능특강 사회탐구영역 생활과 윤리 01부 현대의 삶과 실천 윤리 Page 011 01강 실천 윤리와 윤리 문제에 대한 탐구
#
# #강 01 #쪽 011 #번 001 #문항코드 25015-0001
#
# [문제]
#
# ㉠에 들어갈 내용으로 가장 적절한 것은?
#
# 나는 윤리학이 도덕적 행위의 근거가 되는 도덕 원리나 인간의 성품에 관해 탐구하고, 이를 바탕으로 도덕적 문제 의 해결과 실천 방안을 제시하는 데 주력해야 한다고 본다. 그런데 어떤 사람들은 윤리학이 도덕적 언어의 의미를 분석하고, 도덕적 추론의 정당성을 검증하기 위한 논리를 분석하는 데 주력해야 한다고 주장한다. 나는 이러한 주 장이 ㉠ 고 생각한다.
#
# ① 도덕 규칙의 근거가 되는 원리를 정립해야 함을 강조한다
#
# ② 윤리학이 학문으로서 성립 가능한지를 검토해야 함을 간과한다
#
# ③ 보편적 도덕 원리를 현실의 개별 상황에 적용해야 함을 간과한다
#
# ④ 윤리학이 도덕적 관행에 대한 인과적 서술에 주력해야 함을 강조한다
#
# ⑤ 삶의 구체적 도덕 문제 해결을 윤리학의 핵심 과제로 삼아야 함을 강조한다
#
# [정답/모범답안]
#
# 3
#
# [해설]
#
# 규범 윤리학과 메타 윤리학의 입장 비교
#
# {문제 분석}
#
# 제시문의 ‘나’는 규범 윤리학의 입장이고, ‘어떤 사람들’은 메타 윤리학의 입장이다. ㉠에는 규범 윤리학의 입장에서 메타 윤리학에 대해 평가하는 내용이 들어가야 한다.
#
# {정답 찾기}
#
# ③ 메타 윤리학은 도덕적 언어의 의미 분석과 도덕적 추론의 정당성 검증에 주력하여 현실의 윤 리 문제 해결에 별 관심을 두지 않는다는 비판을 받는다. 따라서 규범 윤리학의 입장에서는 메타 윤리학에 대해 보편적 도덕 원리를 현실의 개별 상황에 적용해야 함을 간과한다는 평가를 내릴 수 있다.
#
# {오답 피하기}
#
# ① 도덕 규칙의 근거가 되는 원리의 정립을 강조하는 것은 메타 윤리학이 아니라 규범 윤리학이 다.
#
# ② 메타 윤리학은 윤리학의 학문적 성립 가능성을 검토한다.
#
# ④ 도덕적 관행에 대한 인과적 서술을 강조하는 것은 기술 윤리학이다.
#
# ⑤ 삶의 구체적 도덕 문제 해결을 핵심 과제로 삼는 것은 실천 윤리학이다.
#
# #강 01 #쪽 011 #번 002 #문항코드 25015-0002
#
# [문제]
#
# 다음 윤리학에서 강조하는 내용으로 옳은 것만을 <보기>에서 고른 것은?
#
# 개인이 지닌 도덕은 삶에 대한 그의 경험의 한 부분이기 때문에 경험적으로 연구될 수 있다. 이와 유사하게 사회적 차원에서도 과학적 탐구를 통해 현실적 도덕에 대한 경험적 지식을 얻을 수 있다. 이처럼 윤리학은 개인의 생활 그 리고 사회의 구조와 기능 속에 존재하는 도덕 현상에 대해 객관적으로 기술하는 것을 목표로 삼아야 한다.
#
# < 보 기 >
#
# ㄱ. 윤리 문제에 대한 가치 중립적인 접근이 필요하다. ㄴ. 윤리학은 도덕 논증의 타당성 분석에 주력해야 한다. ㄷ. 도덕 현상은 과학적으로 기술해야 할 사실의 집합이다. ㄹ. 현실의 도덕 문제 해결을 위한 도덕규범을 정립해야 한다.
#
# ① ㄱ, ㄴ
#
# ② ㄱ, ㄷ
#
# ③ ㄴ, ㄷ
#
# ④ ㄴ, ㄹ
#
# ⑤ ㄷ, ㄹ
#
# [정답/모범답안]
#
# 2
#
# [해설]
#
# 기술 윤리학의 입장 파악
#
# {문제 분석}
#
# 제시문은 기술 윤리학의 입장이다. 기술 윤리학은 개인의 생활과 사회의 구조와 기능 속에 존재 하는 도덕 현상에 대해 객관적으로 기술하는 것을 목표로 삼는다.
#
# {정답 찾기}
#
# ㄱ. 기술 윤리학은 도덕 현상에 대해 객관적으로 기술하는 것을 목표로 삼는다. 따라서 윤리 문 제에 대해 가치 판단을 내리지 않고 가치 중립적으로 접근한다.
#
# ㄷ. 기술 윤리학은 도덕 현상을 과학적으로 기술해야 할 사실의 집합으로 간주하고, 도덕 현상에 대해 가치 판단 없이 객관적으로 관찰하려고 한다.
#
# {오답 피하기}
#
# ㄴ. 도덕 논증의 타당성 분석에 주력해야 한다고 보는 것은 메타 윤리학이다.
#
# ㄹ. 현실의 도덕 문제 해결을 위한 도덕규범의 정립을 주장하는 것은 규범 윤리학이다.
#
# #강 01 #쪽 011 #번 003 #문항코드 25015-0003
# ---
# <class 'unstructured.documents.elements.CompositeElement'>
#  [문제]
#
# ot
#
# 다음 윤리학의 입장에서 부정의 대답을 할 질문으로 가장 적절한 것은?
#
# 현대 사회는 과학 기술의 급속한 발달과 더불어 사회 구조가 복잡해지고 다양해짐에 따라 과거에 없었던 새로운 윤 리 문제에 직면하고 있다. 윤리학은 과학 기술의 발전과 사회 변화로 제기되는 생명, 환경, 정보 등과 관련된 다양 한 도덕적 문제에 윤리 이론을 적용하여 구체적이고 실천적인 지침을 제공하는 것을 핵심 과제로 삼아야 한다.
#
# vege ~S bed Nog poe bee ete ce cee ys yl WK wh
#
# ① 도덕 원리를 현실의 개별 상황에 적용해야 하는가?
#
# woe Bu Hheeh uN
#
# go xx RS
#
# eT mH TF aa eRe 016
#
# ② 도덕적 논의의 의미론적 연구만이 윤리학의 목적인가?
#
# PB ew
#
# ③ 현실에서 일어나는 도덕 문제 해결에 주력해야 하는가?
#
# ④ 현실에서 발생하는 도덕적 딜레마 해결을 중시해야 하는가?
#
# ⑤ 도덕규범을 바탕으로 바람직한 삶의 지침을 제시해야 하는가?
#
# [정답/모범답안]
#
# 2
#
# [해설]
#
# ex = a Ye Tm anee eowe co” Doh aoe ao Pap reehgy ees yhig xR 36
#
# 실천 윤리학의 입장 파악
#
# Pg
#
# 제시문은 실천 윤리학의 입장이다. 실천 윤리학은 현대 사회에서 발생하는 새로운 윤리 문제의 해결을 위해 윤리 이론을 적용하여 구체적이고 실천적인 지침을 제공하는 것을 목표로 한다. {정답 찾기}
#
# oO
#
# ② 도덕적 논의의 의미론적 연구만이 윤리학의 목적이라고 보는 것은 실천 윤리학의 입장이 아
#
# {오답 피하기}
#
# ① 실천 윤리학은 도덕 원리를 현실의 개별 상황에 적용하여 도덕 문제를 해결하려 한다.
#
# oop
#
# ae
#
# 2) 7B ox
#
# we
#
# oe oe
#
# bo
#
# ③ 실천 윤리학은 현대 사회에서 발생하는 도덕 문제 해결에 주력한다.
#
# ④ 실천 윤리학은 현실에서 발생하는 도덕적 딜레마, 즉 도덕적 갈등 상황 해결을 중시한다. ⑤ 실천 윤리학은 현실의 도덕 문제 해결을 위해 도덕규범을 바탕으로 바람직한 삶의 지침을 제 시한다.
#
# #강
#
# 01
#
# #쪽 011
#
# #번 004
#
# #문항코드 25015-0004
#
# [문제]
#
# (가), (나)의 입장에 대한 설명으로 가장 적절한 것은?
#
# (가) 윤리학은 도덕적 판단과 행위를 위한 근본 원리를 탐구함으로써 도덕 판단과 행위의 근거를 제시하고 현실의 윤리적 문제를 해결하는 기준을 제공하는 데 주력해야 한다.
#
# (나) 윤리학은 윤리학의 학문적 성립 가능성을 모색하기 위해 도덕적 언어의 의미 분석과 도덕적 추론 과정의 논리 적 타당성을 검증하는 데 주력해야 한다.
#
# ① (가)는 가치 판단 없이 도덕 문제에 접근해야 한다고 본다.
#
# ② (가)는 도덕 언어의 개념 분석을 윤리학의 주된 목적으로 삼는다.
#
# ③ (나)는 윤리학이 도덕적 담화의 의미 분석보다 도덕규범 정립에 주력해야 한다고 본다. ④ (나)는 윤리학이 현실에서 발생하는 윤리 문제에 대한 해결책 제시를 목표로 삼아야 한다고 본다.
#
# ⑤ (가)는 이론의 타당성 검토를 위해 (나)의 지식을 활용하기도 한다.
#
# [정답/모범답안]
#
# 5
#
# [해설]
#
# H3}
#
# 이론 윤리학과 메타 윤리학의 입장 비교
#
# {문제 분석}
#
# (가)는 이론 윤리학, (나)는 메타 윤리학의 입장이다.
#
# {정답 찾기}
#
# ⑤ 메타 윤리학은 이론 윤리학의 전제를 탐구한다. 이론 윤리학은 이론의 타당성을 검토하기 위 해 이러한 메타 윤리학의 연구 결과를 활용하기도 한다.
#
# {오답 피하기}
#
# ① 가치 판단 없이 도덕 문제에 접근해야 한다고 보는 것은 기술 윤리학이다.
#
# ② 도덕 언어의 개념 분석을 윤리학의 주된 목적으로 삼는 것은 메타 윤리학이다.
#
# ③ 메타 윤리학은 도덕적 담화의 의미 분석에 주력해야 한다고 본다.
#
# ④ 현실에서 발생하는 윤리 문제에 대한 해결책 제시를 목표로 삼아야 한다고 보는 것은 실천 윤리학이다.
#
# #강
#
# =|
#
# 01
#
# #쪽 012
#
# #번 005
#
# #문항코드 25015-0005
#
# [문제]
#
# 갑, 을의 입장으로 적절한 것만을 <보기>에서 고른 것은?
#
# 갑: 윤리학은 삶의 실천적 영역에서 제기되는 도덕 문제를 이해하고, 도덕 원리를 토대로 도덕 문제에 대한 해결책 을 제시하는 것을 목표로 삼아야 한다.
#
# 을: 윤리학은 경험적 탐구를 통해 도덕 현상과 문제를 명확히 기술하고, 기술된 현상 간의 인과 관계를 설명하는 것을 목표로 삼아야 한다.
#
# < 보 기 >
#
# ㄱ. 갑: 윤리학은 행위의 선악 개념의 의미를 분석하는 데 주력해야 한다.
# ---
# <class 'unstructured.documents.elements.CompositeElement'>
#  g™
#
# Fe
#
# a
#
# moe
#
# ㄴ. 갑: 윤리 문제 해결을 위해서는 다양한 학문 분야의 지식을 활용하는 학제적 연구가 필요하다. ㄷ. 을: 윤리학은 한 사회의 도덕규범이 개인과 사회 제도에 미치는 영향을 객관적으로 설명해야 한 다.
#
# eo
#
# ㄹ. 갑과 을: 윤리학은 도덕규범을 정립하여 도덕적 삶의 지침을 제시하는 데 주력해야 한다.
#
# ① ㄱ, ㄴ
#
# ② ㄱ, ㄷ
#
# ③ ㄴ, ㄷ
#
# ④ ㄴ, ㄹ
#
# ⑤ ㄷ, ㄹ
#
# [정답/모범답안]
#
# 3
#
# [해설]
#
# 실천 윤리학과 기술 윤리학의 입장 비교
#
# {문제 분석}
#
# 갑은 실천 윤리학, 을은 기술 윤리학의 입장이다.
#
# {정답 찾기}
#
# ㄴ. 실천 윤리학은 현대 사회의 다양한 분야에서 발생하는 도덕 문제에 대한 해결책 제시를 목표 로 삼는다. 이를 위해 다양한 학문 분야의 지식을 활용하는 학제적 연구의 필요성을 제기한다. ㄷ. 기술 윤리학은 한 사회의 도덕 현상에 대한 객관적 기술을 목표로 삼는다. 즉 한 사회의 도 덕규범이 개인과 사회 제도에 미치는 영향을 객관적으로 설명하는 것을 목표로 삼는다. {오답 피하기}
#
# ㄱ. 행위의 선악 개념과 같은 도덕 언어의 의미 분석에 주력하는 것은 메타 윤리학이다. ㄹ. 도덕적 삶의 지침을 제시하는 데 주력해야 한다고 보는 것은 실천 윤리학에만 해당한다.
#
# #강 01 #번 006 #문항코드 25015-0006
#
# #쪽 012
#
# [문제]
#
# 그림은 수업 장면이다. ㉠~㉢에 대한 설명으로 적절하지 않은 것은?
#
# CIZt HHO SAh= OlZt WHOS Whafot Of Ol7to| MSHS Aotot= Ho] 7| THEO] =AAOS Sr! Ol. LHS at 22H. aoe
#
# ① ㉠에는 행위의 옳고 그름을 판단하는 도덕 원리가 들어간다.
#
# ② ㉠의 타당성 검토를 위해 역할 교환 검사나 보편화 결과 검사를 이용할 수 있다.
#
# ③ ㉡에는 사실의 진위 여부에 대한 판단이 아니라 옳고 그름에 대한 가치 판단이 들어간다.
#
# ④ ㉢에는 ‘인간 배아 복제는 도덕적으로 옳지 않다.’는 내용이 들어간다.
#
# ⑤ ㉢에는 ㉠의 원리와 ㉡의 판단을 근거로 하여 도덕적 옳고 그름을 판단하는 도덕 판단이 들 어간다.
#
# [정답/모범답안]
#
# 3
#
# [해설]
#
# 도덕적 탐구의 과정 이해
#
# {문제 분석}
#
# 제시된 수업 장면은 대전제와 소전제를 거쳐 결론에 이르는 도덕적 탐구의 과정을 보여 주고 있 다. 대전제는 도덕 원리, 소전제는 사실 판단, 결론은 도덕 판단에 해당한다. ㉠에는 ‘인간의 생 명권을 침해하는 행위는 도덕적으로 옳지 않다.’는 도덕 원리가 들어간다. ㉡에는 ‘인간 배아 복제는 인간 배아를 파괴하여 인간의 생명권을 침해하는 행위이다.’라는 사실 판단이 들어간다. ㉢에는 ‘인간 배아 복제는 도덕적으로 옳지 않다.’는 도덕 판단이 들어간다.
#
# {정답 찾기}
#
# ③ ㉡에는 사실의 진위 여부를 판단하는 사실 판단이 들어가야 한다.
#
# {오답 피하기}
#
# ① ㉠에는 행위의 옳고 그름을 가리는 도덕 원리가 들어간다.
#
# ② ㉠에 들어가는 도덕 원리의 타당성 검토를 위해 도덕 원리가 다른 사람들의 처지에서도 받아 들일 수 있는지를 판단하는 역할 교환 검사나 규범적 차원에서 보편화가 가능한지를 검토하는 보편화 결과 검사를 이용할 수 있다.
#
# ④ ㉢에는 ‘인간 배아 복제는 도덕적으로 옳지 않다.’는 도덕 판단이 들어간다.
#
# ⑤ 도덕 판단은 도덕 원리와 사실 판단을 근거로 하여 사실 판단의 대상이 되는 인간의 성품이 나 행위에 대해 도덕적 옳고 그름을 판단하는 것이다. ㉢에는 ㉠의 원리와 ㉡의 판단을 근거로 한 도덕 판단이 들어간다.
#
# 01 #쪽 012 #번 007 #문항코드 25015-0007
#
# #강
#
# [문제]
#
# 그림의 강연자가 지지할 견해로 가장 적절한 것은?
#
# ME Al7t HO N= SLt Alas Ate oh= AL} HAEAl SLot A, Jel 1 AHASS UL Seo AAot= SY S B47| BS AAU AHS S 20| 2/42] YEO] OE S= OSS =F = AS aACMCe AZteHOF SLICh. HASS MSOILt SSS Se GE Of Ss MAME Aloe} Tels 4s AKI2| SS0| SSoHAlES b= le OSs | BE AS FAY Hohok Sf LC} BEor| BE ae S77 B SuCt.
#
# ① 주어진 운명에 순응하여 살아가는 것이 최선의 삶이다. ② 자신이 속한 사회의 관습을 무비판적으로 수용해야 한다.
#
# ③ 세속에서 벗어나 초월적 존재의 가르침에 따라 살아야 한다.
# ---
# <class 'unstructured.documents.elements.CompositeElement'>
#  eee
#
# ④ 자신의 삶을 반성적으로 돌아보는 성찰의 자세를 함양해야 한다.
#
# ⑤ 부귀와 명성을 목표로 하는 삶의 자세를 긍정적으로 인식해야 한다.
#
# [정답/모범답안]
#
# 4
#
# [해설]
#
# 윤리적 성찰의 자세 파악
#
# {문제 분석}
#
# 그림의 강연자는 소크라테스이다. 소크라테스는 검토하지 않는 삶은 살 가치가 없다고 하면서, 인간은 자신의 삶을 성찰하고 변화시킬 수 있는 존재라고 주장하였다.
#
# {정답 찾기}
#
# ④ 소크라테스는 재물이나 명성을 쌓는 데만 마음을 쓰고 진리를 추구하고 영혼이 훌륭해지도록 하는 데 노력하지 않는 사람들의 태도를 비판하면서, 자신의 삶을 반성적으로 성찰하는 자세를 함양할 것을 강조하였다.
#
# {오답 피하기}
#
# ① 소크라테스는 운명에 순응하는 삶이 아니라 진리와 영혼의 훌륭함을 추구하는 삶의 자세를 강조하였다.
#
# ② 소크라테스는 사회의 관습에 대한 무비판적 수용이 아니라 자신의 삶을 검토하는 삶의 자세
#
# 를 강조하였다.
#
# ③ 소크라테스는 세속에서 벗어나 초월적 존재의 가르침에 따르는 삶이 아니라 진리와 영혼의 훌륭함 추구를 위해 자신을 검토하는 삶의 태도를 강조하였다.
#
# ⑤ 소크라테스는 진리와 영혼의 훌륭함을 추구하지 않고 부귀와 명성만을 추구하는 삶의 자세를 부끄러워해야 한다고 보았다.
#
# 01 #쪽 012 #번 008 #문항코드 25015-0008
#
# #강
#
# [문제]
#
# 다음을 주장한 사상가의 입장으로 가장 적절한 것은?
#
# 우리 자신의 의견이 진리라는 것을 정당화하기 위해서는 우리가 어떤 의견을 반박하고 반증할 수 있는 자유를 완전 하게 지닌다는 사실을 인정해야 한다. 사람은 자신의 잘못을 토론과 경험을 통해 바로잡을 수 있는 능력을 지니고 있다. 잘못된 의견과 이에 근거한 행위는 경험을 통해 밝혀진 사실과 토론에서 행해진 논증 앞에 굴복할 수밖에 없 다.
#
# ① 다수가 동의하지 않는 입장은 절대 진리가 될 수 없다.
#
# ② 소수의 의견을 통해 진리를 인식하는 것은 불가능하다.
#
# ③ 반대 없는 만장일치를 통해서만 진리를 획득할 수 있다.
#
# ④ 진리를 얻기 위해서는 오류를 지닌 반대 의견에 대해 불관용해야 한다.
#
# ⑤ 진리 획득을 위해 자기주장의 오류 가능성을 인정하는 태도가 필요하다.
#
# [정답/모범답안]
#
# 5
#
# [해설]
#
# zw
#
# 표현의 자유와 토론에 대한 밀의 입장 파악
#
# {문제 분석}
#
# 제시문은 밀의 주장이다. 밀은 진리의 정당화를 위해서는 표현의 자유가 필요하고, 자신의 잘못 을 토론과 경험을 통해 바로잡을 수 있다고 보았다.
#
# {정답 찾기}
#
# ⑤ 밀은 우리가 자기주장의 오류 가능성을 인정할 때 진리에 다가설 수 있다고 주장하면서, 토론 과 경험을 통해 자기주장의 오류 가능성을 파악할 수 있다고 보았다.
#
# {오답 피하기}
#
# ① 밀은 다수가 동의하는 입장이 모두 진리인 것은 아니라고 주장하면서 다수가 동의하지 않는 입장도 진리가 될 수 있다고 보았다.
#
# ② 밀은 소수의 의견을 통해 진리를 인식할 수 있다고 보면서, 소수의 의견을 자유롭게 제시할 수 있는 표현의 자유를 강조하였다.
#
# ③ 밀은 반대 없는 만장일치를 통해서만 진리를 획득할 수 있다고 보지 않았고, 진리 획득을 위 해서는 다수의 주장에 반대하는 소수의 주장도 필요하다고 보았다.
#
# ④ 밀은 진리를 얻기 위해서는 오류를 지닌 반대 의견에 대해서도 관용해야 한다고 보았다.
#
# #강 01 #쪽 013 #번 001 #문항코드 25015-0009
#
# [문제]
#
# 갑의 입장에 비해 을의 입장이 갖는 상대적 특징을 그림의 ㉠~㉤ 중에서 고른 것은?
#
# 갑: 윤리학은 학문의 목적을 도덕규범의 정립이나 체계화에 두기보다는 윤리학 자체에 대한 비판적 자기 분석을 통 해서 도덕 언어의 의미를 명확히 밝히고, 도덕 추론 과정의 논리적 타당성을 입증하는 데 주력해야 한다. 을: 윤리학은 학문의 목적을 도덕 언어 분석이나 도덕 추론 과정의 논리적 분석에 두기보다는 우리가 마땅히 따라 야 하는 바람직한 도덕적 판단이나 표준 혹은 규칙이 무엇인지를 탐구하고, 도덕적 판단이나 규칙의 정당한 근거를 찾는 데 두어야 한다.
#
# - X: O1ZO| A=SHOF St HAT THO] GMS BASE BS -Y: £4 4=9| Ets ASS Het zy ENB Aste BE -Z: BHO] MNS BEE ES A e|°| 28S SAS BE
#
# ① ㉠
#
# ② ㉡
#
# ③ ㉢
#
# ④ ㉣
#
# ⑤ ㉤
#
# [정답/모범답안]
#
# 3
#
# [해설]
#
# 메타 윤리학과 규범 윤리학의 입장 비교
# ---
# <class 'unstructured.documents.elements.CompositeElement'>
#  {문제 분석}
#
# 갑은 메타 윤리학, 을은 규범 윤리학의 입장이다. 메타 윤리학은 윤리학의 목적을 도덕규범의 정 립이나 체계화에 두지 않고 윤리학 자체에 대한 분석을 통해 윤리학의 방법론적·체계론적 조건 을 탐구하고 그 원리를 확인하는 데 두어야 한다고 본다.
#
# {정답 찾기}
#
# ③ 갑의 입장에 비해 을의 입장은 ‘인간이 추구해야 할 보편 규범의 모색을 강조하는 정도(X)’ 는 높고, ‘도덕 추론의 타당성 검증을 위한 논리적 분석을 강조하는 정도(Y)’는 낮으며, ‘행위 의 선악을 판단하는 도덕 원리의 필요성을 강조하는 정도(Z)’는 높다. 따라서 ㉢이 적절한 위치 이다.
#
# #강 01 #쪽 013 #번 002 #문항코드 25015-0010
#
# [문제]
#
# (가)의 갑, 을의 입장을 (나) 그림으로 탐구하고자 할 때, A~C에 들어갈 적절한 질문만을 <보기> 에서 있는 대로 고른 것은?
#
# ny : BASIS HY, ME Ole DISH 71g BI Bet SAI SOF S Clos SIA Bashi AHO! cy __ £3 2x) chet ASS! Bal oles ASslol sdztAHS ofeISI al FeHsHoF et S: BAjStS ASIA LEH US CHAISE SHY SIS HAY. Bsly. ClRsIIOw BAS} OF AAfolT 2HEPYOS 7/Sobe Ol StoHOF SIC. — (L4)
#
# < 보 기 >
#
# ㄱ. A: 사회의 도덕 문제를 사실 판단의 대상으로 보아야 하는가? ㄴ. B: 현실의 도덕 문제 해결을 위한 실천적 지침을 제시해야 하는가? ㄷ. B: 도덕 판단의 논리적 구조 분석을 윤리학의 목표로 삼아야 하는가? ㄹ. C: 사회의 도덕 관행을 경험 과학적으로 조사할 필요가 있는가?
#
# ① ㄱ, ㄴ
#
# ② ㄱ, ㄷ
#
# ③ ㄴ, ㄹ
#
# ④ ㄱ, ㄷ, ㄹ
#
# ⑤ ㄴ, ㄷ, ㄹ
#
# [정답/모범답안]
#
# 3
#
# [해설]
#
# 실천 윤리학과 기술 윤리학의 입장 비교
#
# {문제 분석}
#
# (가)의 갑은 실천 윤리학, 을은 기술 윤리학의 입장이다. 실천 윤리학은 윤리학이 현실에서 발생 하는 구체적인 도덕 문제에 대한 해결책 마련에 주력해야 한다고 본다. 기술 윤리학은 윤리학이 도덕적 현상을 객관적으로 기술하는 데 주력해야 한다고 본다.
#
# {정답 찾기}
#
# ㄴ. 실천 윤리학은 윤리학이 윤리 이론을 적용하여 현실의 도덕 문제를 해결하기 위한 실천적 지 침을 제시해야 한다고 본다.
#
# ㄹ. 기술 윤리학은 도덕 현상을 객관적으로 기술하기 위해 한 사회의 도덕 관행을 경험 과학적으 로 조사할 필요가 있다고 본다.
#
# {오답 피하기}
#
# ㄱ. 실천 윤리학은 사회의 도덕 문제를 옳고 그름을 판단하는 가치 판단의 대상으로 본다. ㄷ. 도덕 판단의 논리적 구조 분석을 윤리학의 목표로 삼는 것은 메타 윤리학이다.
#
# 01 #쪽 014 #번 003 #문항코드 25015-0011
#
# #강
#
# [문제]
#
# (가)~(다) 윤리학에 대한 설명으로 옳은 것만을 <보기>에서 있는 대로 고른 것은?
#
# (가) 윤리학은 삶에서 구체적으로 발생하는 윤리 문제에 대해 도덕 원리를 근거로 하여 실제적이고 구체적인 해결 책을 모색하는 것을 주된 목표로 삼아야 한다.
#
# (나) 윤리학은 도덕적 행위에 대한 이론적 분석과 정당화를 다룸으로써 현실의 윤리 문제를 해결하는 토대를 제공 하는 이론을 정립하는 것을 주된 목표로 삼아야 한다.
#
# (다) 윤리학은 행위의 옳고 그름과 같은 실천적 물음에 대한 해답 제시가 아니라 도덕 언어의 의미를 분석하고 도 덕적 추론의 타당성을 입증하는 것을 주된 목표로 삼아야 한다.
#
# < 보 기 >
#
# ㄱ. (가)는 현실의 윤리 문제 해결 방안의 근거로 (나)를 활용한다. ㄴ. (나)는 윤리학의 학문적 성립 가능성 연구를 주된 과제로 삼는다. ㄷ. (다)의 지식은 (나)의 이론 정립 과정에 활용되기도 한다. ㄹ. (나)와 (다)는 가치 판단 없이 도덕 이론을 정립하는 데 주력한다.
#
# ① ㄱ, ㄴ
#
# ② ㄱ, ㄷ
#
# ③ ㄴ, ㄹ
#
# ④ ㄱ, ㄷ, ㄹ
#
# ⑤ ㄴ, ㄷ, ㄹ
#
# [정답/모범답안]
#
# 2
#
# [해설]
#
# 실천 윤리학, 이론 윤리학, 메타 윤리학의 입장 비교
#
# {문제 분석}
#
# (가)는 실천 윤리학, (나)는 이론 윤리학, (다)는 메타 윤리학의 입장이다.
# ---

# %%
# 저장
with open("elements.pkl", "wb") as f:
    pickle.dump(elements, f)

# %%
# 불러오기
with open("/content/drive/MyDrive/elements.pkl", "rb") as f:
    elements = pickle.load(f)

# %%
'''
엑셀 파일로 저장

import shutil

folder_path = '/content/figures'
output_zip = '/content/figures.zip'

shutil.make_archive(output_zip.replace('.zip', ''), 'zip', folder_path)
'''

# %% [markdown]
# # 2. 실습 실행

# %%
# 1. 이미지 경로들 가져오기
image_paths = [os.path.join(image_output_dir, f) for f in os.listdir(image_output_dir) if f.lower().endswith((".png", ".jpg", ".jpeg"))]

# %%
# 2. 텍스트 추출
texts= [el.text for el in elements if el.text and el.text.strip() != ""]

# %%
# 3. 텍스트 임베딩: BGE-M3 (수능특강처럼 텍스트가 긴 경우 BAAI/bge-m3 사용)
bge_tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-m3")
bge_model = AutoModel.from_pretrained("BAAI/bge-m3")

# 이미지/텍스트 임베딩: CLIP
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# %%
def embed_text_bge(text):
    inputs = bge_tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=8192)
    with torch.no_grad():
        outputs = bge_model(**inputs)
    return outputs.last_hidden_state[:, 0].cpu().numpy()[0]

def embed_image_clip(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = clip_processor(images=image, return_tensors="pt")
    with torch.no_grad():
        outputs = clip_model.get_image_features(**inputs)
    return outputs[0].cpu().numpy()

# %%
# 4. DummyEmbeddingFunction 선언

class DummyEmbeddingFunction:
    def __init__(self, vectors):
        self.vectors = vectors
        self.i = 0

    def embed_documents(self, texts):
        results = self.vectors[self.i : self.i + len(texts)]
        self.i += len(texts)
        return results

    def embed_query(self, text):
        raise NotImplementedError("Query embedding은 지원하지 않습니다.")

# %%
# 5. docs, vectors 선언

# 텍스트 리스트
text_docs = [Document(page_content=t) for t in texts]
text_vectors = np.array([embed_text_bge(t) for t in texts]).astype("float32")

# 이미지 경로 리스트
image_docs = [Document(page_content="Image", metadata={"image_path": path}) for path in image_paths]
image_vectors = np.array([embed_image_clip(doc.metadata["image_path"]) for doc in image_docs]).astype("float32")

# %%
'''
img_save_path = "/content/drive/MyDrive/img_text_embeddings.pkl"  # 원하는 경로로 지정

with open(img_save_path, "wb") as f:
    pickle.dump({
        "documents": image_docs,
        "vectors": image_vectors,
    }, f)

print(f"✅ 저장 완료: {img_save_path}")


txt_save_path = "/content/drive/MyDrive/text_embeddings.pkl"  # 원하는 경로로 지정

with open(save_path, "wb") as f:
    pickle.dump({
        "documents": text_docs,
        "vectors": text_vectors,
    }, f)

print(f"✅ 저장 완료: {txt_save_path}")
'''
# Out:
# ✅ 저장 완료: /content/drive/MyDrive/img_text_embeddings.pkl
# ✅ 저장 완료: /content/drive/MyDrive/text_embeddings.pkl

# %%
# 6. VectorStore 선언

# 텍스트 벡터스토어
text_embedding_fn = DummyEmbeddingFunction(text_vectors)
vectorstore_text = FAISS.from_documents(
    documents=text_docs,
    embedding=text_embedding_fn
)

# 이미지 벡터스토어
image_embedding_fn = DummyEmbeddingFunction(image_vectors)
vectorstore_image = FAISS.from_documents(
    documents=image_docs,
    embedding=image_embedding_fn
)
# Out:
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
# 7. unified_search

def unified_search(query, top_k=3):
    # 텍스트용 BGE-M3 임베딩
    bge_vector = embed_text_bge(query)
    text_results = vectorstore_text.similarity_search_by_vector(bge_vector, k=top_k)

    # 이미지 검색용 CLIP 텍스트 임베딩
    clip_inputs = clip_processor(text=[query], return_tensors="pt", padding=True)
    with torch.no_grad():
        clip_vector = clip_model.get_text_features(**clip_inputs)[0].cpu().numpy()
    image_results = vectorstore_image.similarity_search_by_vector(clip_vector, k=top_k)

    return {
        "text_results": text_results,
        "image_results": image_results
    }

# %% [markdown]
# # 3. 활용

# %%
query = "행복에 대한 윤리적 관점"
results = unified_search(query)

print("📘 텍스트 검색 결과:")
for r in results["text_results"]:
    print("-", r.page_content[:100])

print("\n🖼 이미지 검색 결과:")
for r in results["image_results"]:
    print("-", r.metadata.get("image_path", "경로 없음"))
# Out:
# 📘 텍스트 검색 결과:
# - eee
#
# ④ 자신의 삶을 반성적으로 돌아보는 성찰의 자세를 함양해야 한다.
#
# ⑤ 부귀와 명성을 목표로 하는 삶의 자세를 긍정적으로 인식해야 한다.
#
# [정답/모범답안]
#
# 4
#
# [해설
# - VAG
#
# ④ B: 윤리학은 도덕 명제의 논리적 구조 분석에 주력해야 함을 간과한다.
#
# ⑤ B: 윤리학은 사회의 관습을 경험 과학적으로 기술하는 데 주력해야 함을 간과한다.
#
# [정답
# - [문제]
#
# ot
#
# 다음 윤리학의 입장에서 부정의 대답을 할 질문으로 가장 적절한 것은?
#
# 현대 사회는 과학 기술의 급속한 발달과 더불어 사회 구조가 복잡해지고 다양해짐에 따라 과거
#
# 🖼 이미지 검색 결과:
# - /content/drive/MyDrive/output_images/figure-69-21.jpg
# - /content/drive/MyDrive/output_images/figure-144-42.jpg
# - /content/drive/MyDrive/output_images/figure-11-4.jpg

# %%
query = "석가모니의 주장"
results = unified_search(query, 5)

print("📘 텍스트 검색 결과:")
for r in results["text_results"]:
    print("-", r.page_content[:1000])

print("\n🖼 이미지 검색 결과:")
for r in results["image_results"]:
    print("-", r.metadata.get("image_path", "경로 없음"))
# Out:
# 📘 텍스트 검색 결과:
# - #강
#
# [문제]
#
# 다음을 주장한 사상가의 입장으로 가장 적절한 것은?
#
# 육체, 느낌, 지각, 행위, 의식[色受想行識]을 즐기고 있는 사람은 괴로움을 즐기고 있는 사람이다. 괴로움을 즐기고 있는 사람은 괴로움에서 벗어날 수 없는 사람이다. 비구들이여, 그대들은 오랫동안 생사(生死)를 거듭하면서 괴로움 을 겪어 왔고, 불행을 겪어 왔으며, 죽어서 묘지를 가득 채워 왔다. 그러므로 바로 지금이 모든 행위에 대해서 싫어 하는 생각을 비워 내기에 적당한 때이며, 탐욕을 버리기에 적당한 때이며, 이 모든 괴로움에서 벗어나 해탈을 얻기 에 적당한 때이다.
#
# ① 괴로움의 생성과 소멸에는 모두 원인이 있음을 깨달아야 한다.
#
# ② 마음속의 번뇌를 제거하여 불변의 오온(五蘊)을 형성해야 한다.
#
# ③ 극단적인 고행의 수련을 통해서만 중도(中道)에 도달할 수 있다.
#
# ④ 욕망을 절제하고 무명(無明)에 도달해야 깨달음을 얻을 수 있다.
#
# ⑤ 탐욕을 제거하기 위해 자아가 무상(無常)하지 않음을 깨달아야 한다.
#
# [정답/모범답안]
#
# 1
#
# [해설]
#
# 석가모니의 입장 파악
#
# {문제 분석}
#
# 제시문은 석가모니의 주장이다. 석가모니는 인간이 삶과 죽음을 반복하는 윤회를 거듭하면서 고 통을 겪는다고 보고, 깨달음을 얻어 해탈에 이르러야 윤회의 고통에서 벗어날 수 있다고 보았다. {정답 찾기}
#
# ① 석가모니는 모든 존재와 현상에는 원인과 조건이 있다고 보았다. 그는 괴로움의 생성과 소멸 에도 모두 원인이 있다고 보았다.
#
# {오답 피하기}
#
# ② 석가모니는 인간을 구성하는 다섯 가지 요소인 오온(五蘊)도 고정불변한 것이 아니라 일시적
#
# 인 것이라고 보았다.
#
# ③ 석가모니가 제시한 중도의 수행 방법은 지나치게 쾌락에 빠지지도 않고 지나치게 고행에 빠 지지도 않는 것이다.
#
# ④ 무명(無明)은 진리를 깨닫지 못한 상태로, 석가모니는 무명에서 벗어나 참된 깨달음에 도달해
#
# 야 한다고 보았다.
#
# ⑤ 석가모니는 자아도 무상하다고 보았다. 즉 자아가 고정불변한 것이 아니라 생멸 변화한다고 본 것이다.
#
# #강 02
# - [문제]
#
# 다음을 주장한 사상가의 입장에서 부정의 대답을 할 질문으로 가장 적절한 것은?
#
# 어떤 유익한 법[善法]이든 그것은 모두 네 가지 성스러운 진리에 포함된다. 네 가지 진리란 괴로움의 성스러운 진리 [苦諦], 괴로움의 일어남의 성스러운 진리[集諦], 괴로움의 소멸의 성스러운 진리[滅諦], 괴로움의 소멸로 인도하는 도닦음의 성스러운 진리[道諦]이다.
#
# ① 인간이 겪는 고통은 무명(無明)과 애욕으로 생겨나는가?
#
# ② 세상의 모든 존재와 현상에는 원인과 조건이 존재하는가?
#
# ③ 만물의 상호 의존성을 자각하고 자비의 사랑을 실천해야 하는가?
#
# ④ 고통에서 벗어나기 위해서는 연기(緣起)에 대한 깨달음이 필요한가?
#
# ⑤ 진리를 깨닫기 위해서는 만물이 상호 독립적 실체임을 파악해야 하는가?
#
# [정답/모범답안]
#
# 5
#
# [해설]
#
# S|
#
# 석가모니의 입장 파악
#
# {문제 분석}
#
# 제시문은 석가모니의 주장이다. 석가모니는 수행을 통해 깨달은 네 가지 성스러운 진리인 사성제 (四聖諦)를 제시하였다.
#
# {정답 찾기}
#
# ⑤ 석가모니는 진리를 깨닫기 위해서는 만물을 상호 독립적인 실체로 보지 말고 만물의 상호 연 관성을 파악해야 한다고 주장하였다.
#
# {오답 피하기}
#
# ① 석가모니는 인간의 삶이 본질적으로 고통일 수밖에 없으며, 인간이 겪는 고통은 무명과 애욕
#
# 으로 생겨난다고 보았다.
#
# ② 석가모니는 세상의 모든 존재와 현상에 원인과 조건이 있다는 연기적 세계관을 제시하였다. ③ 석가모니는 모든 것이 상호 관계 속에서 존재한다는 연기의 법칙을 깨달으면, 자비의 마음이 저절로 생겨나 이를 실천할 수 있다고 보았다.
#
# ④ 석가모니는 연기에 대한 깨달음을 얻으면 고통과 번뇌에서 벗어날 수 있다고 보았다.
#
# #강 02
#
# #쪽 023
#
# #번 004
#
# #문항코드 25015-0020
#
# [문제]
#
# 갑, 을 사상가들의 입장으로 적절하지 않은 것은?
#
# 갑: 성인(聖人)은 무위(無爲)로써 일을 처리하고, 말로 하지 않는 가르침을 수행한다. 모든 일이 생겨나도 마다하지 않고, 모든 것을 이루나 가지려
# - {문제 분석}
#
# 갑은 플라톤, 을은 에피쿠로스이다. 플라톤은 인간이 무엇인가를 순수하게 인식하려면 육체에서 벗어나야 하며 오직 영혼만을 사용하여 사물 그 자체를 보아야 한다고 강조하면서, 죽었을 때라 야 우리는 간절히 바라는 지혜를 얻을 수 있다고 주장하였다. 에피쿠로스는 죽음이 인간에게 아 무것도 아닌 것은 인간이 존재하는 한 죽음은 우리와 함께 있지 않으며, 죽음이 오면 우리는 이 미 존재하지 않기 때문이라고 보았다.
#
# {정답 찾기}
#
# ② 플라톤은 죽음 이후 감각이 아닌 영혼으로 참된 실재를 알게 된다고 보았다.
#
# {오답 피하기}
#
# ① 플라톤은 죽음 이후에도 영혼은 육체로부터 벗어나 영원불멸할 수 있다고 보았다.
#
# ③ 에피쿠로스는 오래 사는 것보다는 즐겁게 사는 것이 중요하다고 주장하였다.
#
# ④ 에피쿠로스는 죽음이 인간에게 고통을 줄 수 없으므로 이를 깨달은 현명한 사람은 삶의 중단 을 두려워하지 않는다고 주장하였다.
#
# ⑤ 플라톤과 에피쿠로스는 모두 죽음을 두려워하는 사람은 지혜롭지 못한 사람이라고 보았다.
#
# #쪽 038
#
# #강 03 #번 003 #문항코드 25015-0045
#
# [문제]
#
# 갑, 을 사상가들의 입장에 대한 설명으로 가장 적절한 것은?
#
# 갑: 사람들은 지식에 얽매여 몸과 마음을 상하게 하지만 성인(聖人)은 재주와 지혜를 버린다. 성인은 유구한 천지의 운행에 몸을 맡기나 변하지 않으며, 만물을 있는 그대로 긍정하여 자기 안에 포함한다. 이것이 바로 성인의 모습이 다. 인간이 삶에 집착하는 것은 어리석은 일이며, 죽음을 싫어하는 것은 나그네가 고향에 돌아감을 잊고 있는 것과 같은 것인지도 모른다. 인생도 긴 꿈을 꾸고 있는 것과 같으며, 참된 깨달음에 도달한 사람만이 그것이 꿈인 줄 안 다. 그러나 어리석게도 사람들은 그들이 깨어 있다고 믿기에 사소한 지식을 과시하고, 귀천의 차별을 일삼는 것이 다.
#
# 을: 마땅히 눈은 덧없는 것이라고 바르게 관찰하라. 이와 같이 관찰하면 그것을 바른 관찰이라 하느니라. 바르게 관 찰하기 때문에 싫어하는 마음이 생
# - eee
#
# ④ 자신의 삶을 반성적으로 돌아보는 성찰의 자세를 함양해야 한다.
#
# ⑤ 부귀와 명성을 목표로 하는 삶의 자세를 긍정적으로 인식해야 한다.
#
# [정답/모범답안]
#
# 4
#
# [해설]
#
# 윤리적 성찰의 자세 파악
#
# {문제 분석}
#
# 그림의 강연자는 소크라테스이다. 소크라테스는 검토하지 않는 삶은 살 가치가 없다고 하면서, 인간은 자신의 삶을 성찰하고 변화시킬 수 있는 존재라고 주장하였다.
#
# {정답 찾기}
#
# ④ 소크라테스는 재물이나 명성을 쌓는 데만 마음을 쓰고 진리를 추구하고 영혼이 훌륭해지도록 하는 데 노력하지 않는 사람들의 태도를 비판하면서, 자신의 삶을 반성적으로 성찰하는 자세를 함양할 것을 강조하였다.
#
# {오답 피하기}
#
# ① 소크라테스는 운명에 순응하는 삶이 아니라 진리와 영혼의 훌륭함을 추구하는 삶의 자세를 강조하였다.
#
# ② 소크라테스는 사회의 관습에 대한 무비판적 수용이 아니라 자신의 삶을 검토하는 삶의 자세
#
# 를 강조하였다.
#
# ③ 소크라테스는 세속에서 벗어나 초월적 존재의 가르침에 따르는 삶이 아니라 진리와 영혼의 훌륭함 추구를 위해 자신을 검토하는 삶의 태도를 강조하였다.
#
# ⑤ 소크라테스는 진리와 영혼의 훌륭함을 추구하지 않고 부귀와 명성만을 추구하는 삶의 자세를 부끄러워해야 한다고 보았다.
#
# 01 #쪽 012 #번 008 #문항코드 25015-0008
#
# #강
#
# [문제]
#
# 다음을 주장한 사상가의 입장으로 가장 적절한 것은?
#
# 우리 자신의 의견이 진리라는 것을 정당화하기 위해서는 우리가 어떤 의견을 반박하고 반증할 수 있는 자유를 완전 하게 지닌다는 사실을 인정해야 한다. 사람은 자신의 잘못을 토론과 경험을 통해 바로잡을 수 있는 능력을 지니고 있다. 잘못된 의견과 이에 근거한 행위는 경험을 통해 밝혀진 사실과 토론에서 행해진 논증 앞에 굴복할 수밖에 없 다.
#
# ① 다수가 동의하지 않는 입장은 절대 진리가 될 수 없다.
#
# ② 소수의 의견을 통해 진리를 인식하는 것은 불가능하다.
#
# ③ 반대 없는 만장일치를 통해서만 진리를 획득할 수 있다.
#
# ④ 진리를 얻
# - {오답 피하기}
#
# ① 칼뱅은 소명에 따른 노동을 통해 부를 획득하는 것을 긍정하였고, 이를 신의 축복으로 보았
#
# 다.
#
# ② 칼뱅에 따르면 신은 인간이 모든 일을 혼란에 빠뜨리지 않도록 하기 위해 각자에게 각기 다 른 삶의 양식, 즉 소명을 부여하였다.
#
# ③ 베버에 따르면 프로테스탄티즘은 부의 추구를 도덕적으로 허용하여 합리적 재산 축적을 인정 하였으며, 과도한 소비를 반대하였다.
#
# ④ 베버에 따르면 프로테스탄티즘의 금욕주의는 직업 활동을 통한 부의 추구를 인정하였지만, 부 를 목적 그 자체로 추구하는 것은 부정하였다.
#
# #강 06 #쪽 068 #번 005 #문항코드 25015-0093
#
# [문제]
#
# 다음을 주장한 사상가의 입장으로 적절한 것만을 <보기>에서 있는 대로 고른 것은?
#
# 인간은 동물과 달리 욕구 충족을 위해 합목적적 활동 안에서 노동 수단을 통해 자연 등의 노동 대상을 효율적으로 가공하고 변형한다. 동시에 인간은 노동 과정에서 자신의 본질도 변화시켜, 그 본질에 잠재된 능력을 발전시킨다. 그런데 자본주의 체제에서 노동자는 부를 많이 생산하면 할수록, 그의 생산의 힘과 범위가 증대될수록 더 가난해진 다. 노동자가 상품을 더 많이 창조할수록 그는 더 값싼 상품이 된다.
#
# < 보 기 >
#
# ㄱ. 인간은 노동을 통해 자신의 본질을 실현하고 발전시킬 수 있다. ㄴ. 생산 수단의 사유화를 철폐함으로써 인간 소외를 극복할 수 있다. ㄷ. 자본주의 체제에서 노동자의 노동은 자발적인 것이 아니라 강제된 것이다. ㄹ. 모든 구성원이 능력에 따라 일하고 일한 만큼 분배받는 사회가 이상 사회이다.
#
# ① ㄱ, ㄷ
#
# ② ㄱ, ㄹ
#
# ③ ㄴ, ㄹ
#
# ④ ㄱ, ㄴ, ㄷ
#
# ⑤ ㄴ, ㄷ, ㄹ
#
# [정답/모범답안]
#
# 4
#
# [해설]
#
# 노동에 대한 마르크스의 입장 이해
#
# {문제 분석}
#
# 제시문은 마르크스의 주장이다. 마르크스는 자본주의 체제에서 노동자는 자신의 본질을 실현하기 위한 노동을 하는 것이 아니라 자본에 예속되어 생산을 위한 수단으로 전락한다고 주장하였다. {정답 찾기}
#
# ㄱ. 마르크스
#
# 🖼 이미지 검색 결과:
# - /content/drive/MyDrive/output_images/figure-69-21.jpg
# - /content/drive/MyDrive/output_images/figure-11-4.jpg
# - /content/drive/MyDrive/output_images/figure-1-1.jpg
# - /content/drive/MyDrive/output_images/figure-144-42.jpg
# - /content/drive/MyDrive/output_images/figure-74-23.jpg

# %% [markdown]
# # 4. retriever 활용

# %%
retriever_text = vectorstore_text.as_retriever(search_type="similarity", search_kwargs={"k": 3})
retriever_image = vectorstore_image.as_retriever(search_type="similarity", search_kwargs={"k": 3})

# %%
from langchain.schema import BaseRetriever, Document
from typing import List
from pydantic import PrivateAttr
import torch

class UnifiedMultiModalRetriever(BaseRetriever):
    _retriever_text: Any = PrivateAttr()
    _retriever_image: Any = PrivateAttr()

    def __init__(self, retriever_text, retriever_image):
        super().__init__()
        self._retriever_text = retriever_text
        self._retriever_image = retriever_image

    def _get_relevant_documents(self, query: str) -> List[Document]:
        # 텍스트 임베딩 → 텍스트 검색
        bge_vector = embed_text_bge(query)
        text_results = vectorstore_text.similarity_search_by_vector(bge_vector, k=3)

        # CLIP 임베딩 → 이미지 검색
        clip_inputs = clip_processor(text=[query], return_tensors="pt", padding=True)
        with torch.no_grad():
            clip_vector = clip_model.get_text_features(**clip_inputs)[0].cpu().numpy()
        image_results = vectorstore_image.similarity_search_by_vector(clip_vector, k=3)

        return text_results + image_results

# %%
retriever = UnifiedMultiModalRetriever(retriever_text, retriever_image)

results = retriever.get_relevant_documents("프롬의 주장은 뭘까?")

for doc in results:
    if "image_path" in doc.metadata:
        print("🖼 이미지:", doc.metadata["image_path"])
    else:
        print("📘 텍스트:", doc.page_content[:1000])
# Out:
# 📘 텍스트: @B6eovoe
#
# ③ 사랑은 자신과 상대방의 생동감을 함께 고양하는 활동이다.
#
# ④ 사랑은 상대를 위한 물질적·정신적 희생을 전제하지 않는다.
#
# ⑤ 사랑은 상대에게 정서적으로 예속되는 수동적인 감정이 아니다.
#
# [정답/모범답안]
#
# 2
#
# [해설]
#
# 프롬의 사상적 입장 이해
#
# {문제 분석}
#
# 제시문은 프롬의 주장이다. 프롬에 따르면 사랑은 능동적인 활동으로, 상대방의 인격과 자신의 인격을 존중하며 서로의 생동감을 고양시키는 것이다.
#
# {정답 찾기}
#
# ② 프롬에 따르면 사랑은 자신의 입장을 고수하거나 자신의 입장에 근거하여 상대를 살피는 것 이 아니다.
#
# {오답 피하기}
#
# ① 프롬에 따르면 사랑은 사랑하는 상대가 서로의 개성을 긍정하는 조화를 지향하는 것이다.
#
# ③ 프롬은 사랑이 자신과 상대방의 생동감을 함께 고양하는 능동적인 활동이라고 보았다.
#
# ④ 프롬은 사랑이 상대를 위한 희생을 전제로 하는 것이 아니라고 보았다.
#
# ⑤ 프롬은 사랑이 수동적인 감정이 아니라 능동적인 활동이라고 보았다.
#
# 05 #쪽 058 #번 003 #문항코드 25015-0077
#
# #강
#
# [문제]
#
# 다음 사상의 입장으로 적절한 것만을 <보기>에서 있는 대로 고른 것은?
#
# 임금과 신하 간에는 의리가 있어야 하고, 부모와 자녀 간에는 친함이 있어야 하고, 남편과 부인간에는 분별이 있어 야 하고, 친구 간에는 믿음이 있어야 하고, 어른과 아이 간에는 차례가 있어야 한다.
#
# < 보 기 >
#
# ㄱ. 부자(父子)간의 효는 사회적 관계로 확장될 수 있다.
#
# ㄴ. 부부간에 서로 손님처럼 대하는 것은 예의에 어긋난다.
#
# ㄷ. 가족은 서로 살펴 친애(親愛)의 마음을 잃지 않도록 해야 한다.
#
# ① ㄱ
#
# uous r4orgr CW8neB®@
#
# ② ㄴ
#
# ⑤ ㄱ, ㄴ, ㄷ
#
# [정답/모범답안]
#
# 3
#
# [해설]
#
# 가족 윤리에 대한 유교의 관점 이해
#
# {문제 분석}
#
# 제시문은 유교의 관점으로 군신, 부자, 부부, 친구, 장유 간의 도리에 대해 설명하고 있다. {정답 찾기}
#
# ㄱ. 유교에서는 부자간의 도가 사회적 차원으로 확대
# 📘 텍스트: ④ 레건은 식물이 자신의 삶을 영위할 수 있는 능력이 있다고 보지 않았다.
#
# 교재명 EBS 2026학년도 수능특강 사회탐구영역 생활과 윤리 02부 생명과 윤리 Page 055 05강 사랑과 성 윤리 #강 05 #쪽 055 #번 001 #문항코드 25015-0067
#
# [문제]
#
# a
#
# 다음을 주장한 사상가의 입장으로 가장 적절한 것은?
#
# ee
#
# 인간과의 융합에 대한 욕망은 인간의 가장 강력한 갈망이다. 그것은 가장 기본적인 열정이고 인류를, 집단을, 가족 을, 사회를 결합하는 힘이다. 이 욕구를 만족시키지 못하면 발광 또는 자기 파괴, 타인 파괴가 일어난다. 사랑이 없 으면 인간성은 존재하지 못한다. 그런데 성숙한 사랑은 자신의 통합성, 즉 개성을 유지하는 상태에서의 합일이다. 사랑은 인간에게 능동적인 힘이다. 곧 인간을 동료에게서 분리하는 벽을 허물어 버리는 힘, 인간을 타인과 결합하 는 힘이다. 사랑은 인간으로 하여금 고립감과 분리감을 극복하게 하면서도 각자의 특성을 허용하고 자신의 통합성 을 유지시킨다. 사랑에서는 두 존재가 하나로 되면서도 둘로 남아 있다는 역설이 성립한다.
#
# ① 사랑은 자신의 입장에서 상대방을 이해하는 것이다.
#
# ② 사랑은 상대방을 자신이 원하는 대로 바꾸는 것이다.
#
# ③ 사랑은 자신과 상대방이 전적으로 하나가 되는 것이다.
#
# ④ 사랑은 상대를 존중하면서 인격적 관계를 갖는 활동이다.
#
# ⑤ 사랑은 상대로부터 사랑받아야 의미가 있는 수동적인 것이다.
#
# [정답/모범답안]
#
# 4
#
# [해설]
#
# 사랑에 대한 프롬의 입장 이해
#
# {문제 분석}
#
# 제시문은 프롬의 주장이다. 프롬은 사랑이 서로를 인격적인 존재로 바라보게 한다는 점에서 중요 한 윤리적 의미를 지니고 있고, 진정한 사랑은 인간의 온전한 인격적 관계 속에서 성립할 수 있 다고 보았다.
#
# {정답 찾기}
#
# ④ 프롬에 따르면 사랑은 상대를 존중하면서 인격적 관계를 갖는 능동적인 활동이다.
#
# {오답 피하기}
#
# ① 프롬은 자신의 입장보다는 상대의 입장에서 상대를 이해하는 사랑의 기술을 강조하였다. ②
# 📘 텍스트: {오답 피하기}
#
# ① 칼뱅은 소명에 따른 노동을 통해 부를 획득하는 것을 긍정하였고, 이를 신의 축복으로 보았
#
# 다.
#
# ② 칼뱅에 따르면 신은 인간이 모든 일을 혼란에 빠뜨리지 않도록 하기 위해 각자에게 각기 다 른 삶의 양식, 즉 소명을 부여하였다.
#
# ③ 베버에 따르면 프로테스탄티즘은 부의 추구를 도덕적으로 허용하여 합리적 재산 축적을 인정 하였으며, 과도한 소비를 반대하였다.
#
# ④ 베버에 따르면 프로테스탄티즘의 금욕주의는 직업 활동을 통한 부의 추구를 인정하였지만, 부 를 목적 그 자체로 추구하는 것은 부정하였다.
#
# #강 06 #쪽 068 #번 005 #문항코드 25015-0093
#
# [문제]
#
# 다음을 주장한 사상가의 입장으로 적절한 것만을 <보기>에서 있는 대로 고른 것은?
#
# 인간은 동물과 달리 욕구 충족을 위해 합목적적 활동 안에서 노동 수단을 통해 자연 등의 노동 대상을 효율적으로 가공하고 변형한다. 동시에 인간은 노동 과정에서 자신의 본질도 변화시켜, 그 본질에 잠재된 능력을 발전시킨다. 그런데 자본주의 체제에서 노동자는 부를 많이 생산하면 할수록, 그의 생산의 힘과 범위가 증대될수록 더 가난해진 다. 노동자가 상품을 더 많이 창조할수록 그는 더 값싼 상품이 된다.
#
# < 보 기 >
#
# ㄱ. 인간은 노동을 통해 자신의 본질을 실현하고 발전시킬 수 있다. ㄴ. 생산 수단의 사유화를 철폐함으로써 인간 소외를 극복할 수 있다. ㄷ. 자본주의 체제에서 노동자의 노동은 자발적인 것이 아니라 강제된 것이다. ㄹ. 모든 구성원이 능력에 따라 일하고 일한 만큼 분배받는 사회가 이상 사회이다.
#
# ① ㄱ, ㄷ
#
# ② ㄱ, ㄹ
#
# ③ ㄴ, ㄹ
#
# ④ ㄱ, ㄴ, ㄷ
#
# ⑤ ㄴ, ㄷ, ㄹ
#
# [정답/모범답안]
#
# 4
#
# [해설]
#
# 노동에 대한 마르크스의 입장 이해
#
# {문제 분석}
#
# 제시문은 마르크스의 주장이다. 마르크스는 자본주의 체제에서 노동자는 자신의 본질을 실현하기 위한 노동을 하는 것이 아니라 자본에 예속되어 생산을 위한 수단으로 전락한다고 주장하였다. {정답 찾기}
#
# ㄱ. 마르크스
# 🖼 이미지: /content/drive/MyDrive/output_images/figure-69-21.jpg
# 🖼 이미지: /content/drive/MyDrive/output_images/figure-175-52.jpg
# 🖼 이미지: /content/drive/MyDrive/output_images/figure-144-42.jpg
